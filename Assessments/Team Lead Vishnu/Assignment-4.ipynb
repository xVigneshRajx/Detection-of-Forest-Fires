# %%
pip install contractions
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting contractions
#   Downloading contractions-0.1.72-py2.py3-none-any.whl (8.3 kB)
# Collecting textsearch>=0.0.21
#   Downloading textsearch-0.0.24-py2.py3-none-any.whl (7.6 kB)
# Collecting anyascii
#   Downloading anyascii-0.3.1-py3-none-any.whl (287 kB)
#      |████████████████████████████████| 287 kB 13.7 MB/s
# Collecting pyahocorasick
#   Downloading pyahocorasick-1.4.4-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (106 kB)
#      |████████████████████████████████| 106 kB 68.5 MB/s
# Installing collected packages: pyahocorasick, anyascii, textsearch, contractions
# Successfully installed anyascii-0.3.1 contractions-0.1.72 pyahocorasick-1.4.4 textsearch-0.0.24

# %%
pip install pad_sequences
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pad_sequences
#   Downloading pad-sequences-0.6.1.tar.gz (9.5 kB)
# Building wheels for collected packages: pad-sequences
#   Building wheel for pad-sequences (setup.py) ... done
#   Created wheel for pad-sequences: filename=pad_sequences-0.6.1-py3-none-any.whl size=10217 sha256=593026c6344a2b68297591185024fbaf911891aa853bb0f0496bf36de0b86b3e
#   Stored in directory: /root/.cache/pip/wheels/3f/80/05/48e28be7b6bde8b3378f747f50bc32a87cb281c2e89ae74500
# Successfully built pad-sequences
# Installing collected packages: pad-sequences
# Successfully installed pad-sequences-0.6.1

# %%
import pandas as pd
import numpy as np
import re
import collections
import contractions
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use('dark_background')
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
import warnings
warnings.simplefilter(action='ignore', category=Warning)
import keras
from keras.layers import Dense, Embedding, LSTM, Dropout
from keras.models import Sequential
from keras.preprocessing.text import Tokenizer
import pad_sequences
import pickle

# %%
df = pd.read_csv("/content/drive/MyDrive/spam.csv", encoding='latin-1')
df.head()
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
df.shape
# Out:
# (5572, 5)

# %%
df.drop(["Unnamed: 2", "Unnamed: 3", "Unnamed: 4"], axis=1, inplace=True)

# %%
df.columns = ["SpamHam","Tweet"]

# %%
sns.countplot(df["SpamHam"])

# %%
def word_count_plot(df):
     # finding words along with count
     word_counter = collections.Counter([word for sentence in df for word in sentence.split()])
     most_count = word_counter.most_common(30) # 30 most common words
     # sorted data frame
     most_count = pd.DataFrame(most_count, columns=["Word", "Count"]).sort_values(by="Count")
     most_count.plot.barh(x = "Word", y = "Count", color="green", figsize=(10, 15))
word_count_plot(df["Tweet"])

# %%
pip install stopwords
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting stopwords
#   Downloading stopwords-1.0.0-py2.py3-none-any.whl (37 kB)
# Installing collected packages: stopwords
# Successfully installed stopwords-1.0.0

# %%
import nltk
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %%
from nltk.corpus import stopwords

# %%
lem = WordNetLemmatizer()
def preprocessing(df):
      sms = contractions.fix(df) # converting shortened words to original (Eg:"I'm" to "I am")
      sms = sms.lower() # lower casing the sms
      sms = re.sub(r'https?://S+|www.S+', "", sms).strip() #removing url
      sms = re.sub("[^a-z ]", "", sms) # removing symbols and numbes
      sms = sms.split() #splitting
      # lemmatization and stopword removal
      sms = [lem.lemmatize(word) for word in sms if not word in set(stopwords.words("english"))]
      sms = " ".join(sms)
      return sms
X = df['Tweet'].apply(preprocessing)

# %%
word_count_plot(X)

# %%
from sklearn.preprocessing import LabelEncoder
lb_enc = LabelEncoder()
y = lb_enc.fit_transform(df["SpamHam"])

# %%
tokenizer = Tokenizer() #initializing the tokenizer
tokenizer.fit_on_texts(X)# fitting on the sms data
text_to_sequence = tokenizer.texts_to_sequences(X)

# %%
for i in range(5):
           print("Text               : ",X[i] )
           print("Numerical Sequence : ", text_to_sequence[i])
# Out:
# Text               :  go jurong point crazy available bugis n great world la e buffet cine got amore wat
# Numerical Sequence :  [3, 3575, 255, 549, 522, 1028, 35, 56, 236, 845, 80, 2411, 1029, 9, 3576, 70]
# Text               :  ok lar joking wif oni
# Numerical Sequence :  [6, 220, 1173, 328, 1539]
# Text               :  free entry wkly comp win fa cup final tkts st may text fa receive entry questionstd txt ratetcs apply over
# Numerical Sequence :  [5, 342, 582, 724, 92, 1540, 846, 478, 1541, 147, 175, 17, 1540, 221, 342, 2412, 23, 2413, 263, 2414]
# Text               :  dun say early hor c already say
# Numerical Sequence :  [142, 48, 256, 2415, 69, 75, 48]
# Text               :  nah think go usf life around though
# Numerical Sequence :  [774, 33, 3, 725, 86, 121, 195]

# %%
tokenizer.index_word
# Out:
# {1: 'call',
#  2: 'get',
#  3: 'go',
#  4: 'know',
#  5: 'free',
#  6: 'ok',
#  7: 'ltgt',
#  8: 'day',
#  9: 'got',
#  10: 'want',
#  11: 'come',
#  12: 'like',
#  13: 'love',
#  14: 'going',
#  15: 'good',
#  16: 'time',
#  17: 'text',
#  18: 'send',
#  19: 'message',
#  20: 'need',
#  21: 'one',
#  22: 'today',
#  23: 'txt',
#  24: 'home',
#  25: 'lor',
#  26: 'see',
#  27: 'sorry',
#  28: 'stop',
#  29: 'r',
#  30: 'still',
#  31: 'back',
#  32: 'mobile',
#  33: 'think',
#  34: 'reply',
#  35: 'n',
#  36: 'take',
#  37: 'tell',
#  38: 'phone',
#  39: 'new',
#  40: 'week',
#  41: 'later',
#  42: 'da',
#  43: 'hi',
#  44: 'please',
#  45: 'cannot',
#  46: 'make',
#  47: 'tomorrow',
#  48: 'say',
#  49: 'night',
#  50: 'claim',
#  51: 'well',
#  52: 'thing',
#  53: 'much',
#  54: 'dear',
#  55: 'oh',
#  56: 'great',
#  57: 'hey',
#  58: 'pls',
#  59: 'would',
#  60: 'give',
#  61: 'number',
#  62: 'way',
#  63: 'happy',
#  64: 'friend',
#  65: 'work',
#  66: 'hope',
#  67: 'u',
#  68: 'let',
#  69: 'c',
#  70: 'wat',
#  71: 'prize',
#  72: 'right',
#  73: 'yes',
#  74: 'min',
#  75: 'already',
#  76: 'ask',
#  77: 'really',
#  78: 'yeah',
#  79: 'said',
#  80: 'e',
#  81: 'k',
#  82: 'babe',
#  83: 'co',
#  84: 'p',
#  85: 'amp',
#  86: 'life',
#  87: 'meet',
#  88: 'thanks',
#  89: 'morning',
#  90: 'year',
#  91: 'last',
#  92: 'win',
#  93: 'miss',
#  94: 'service',
#  95: 'cash',
#  96: 'find',
#  97: 'ill',
#  98: 'feel',
#  99: 'lol',
#  100: 'anything',
#  101: 'every',
#  102: 'tone',
#  103: 'nokia',
#  104: 'sure',
#  105: 'pick',
#  106: 'also',
#  107: 'soon',
#  108: 'b',
#  109: 'contact',
#  110: 'keep',
#  111: 'something',
#  112: 'care',
#  113: 'sent',
#  114: 'urgent',
#  115: 'could',
#  116: 'buy',
#  117: 'place',
#  118: 'next',
#  119: 'first',
#  120: 'guy',
#  121: 'around',
#  122: 'even',
#  123: 'tonight',
#  124: 'show',
#  125: 'went',
#  126: 'customer',
#  127: 'help',
#  128: 'someone',
#  129: 'wish',
#  130: 'per',
#  131: 'wait',
#  132: 'many',
#  133: 'nice',
#  134: 'money',
#  135: 'chat',
#  136: 'ya',
#  137: 'sleep',
#  138: 'wan',
#  139: 'word',
#  140: 'always',
#  141: 'late',
#  142: 'dun',
#  143: 'people',
#  144: 'leave',
#  145: 'name',
#  146: 'end',
#  147: 'st',
#  148: 'v',
#  149: 'waiting',
#  150: 'gud',
#  151: 'told',
#  152: 'hour',
#  153: 'tc',
#  154: 'x',
#  155: 'lot',
#  156: 'minute',
#  157: 'getting',
#  158: 'girl',
#  159: 'guaranteed',
#  160: 'yet',
#  161: 'thk',
#  162: 'coming',
#  163: 'box',
#  164: 'month',
#  165: 'done',
#  166: 'hello',
#  167: 'smile',
#  168: 'try',
#  169: 'thought',
#  170: 'person',
#  171: 'haha',
#  172: 'talk',
#  173: 'class',
#  174: 'best',
#  175: 'may',
#  176: 'live',
#  177: 'mean',
#  178: 'offer',
#  179: 'th',
#  180: 'fine',
#  181: 'finish',
#  182: 'lunch',
#  183: 'man',
#  184: 'job',
#  185: 'line',
#  186: 'stuff',
#  187: 'use',
#  188: 'car',
#  189: 'sm',
#  190: 'bit',
#  191: 'draw',
#  192: 'ppm',
#  193: 'holiday',
#  194: 'heart',
#  195: 'though',
#  196: 'yup',
#  197: 'trying',
#  198: 'never',
#  199: 'special',
#  200: 'meeting',
#  201: 'plan',
#  202: 'long',
#  203: 'better',
#  204: 'account',
#  205: 'dat',
#  206: 'start',
#  207: 'chance',
#  208: 'cool',
#  209: 'ready',
#  210: 'problem',
#  211: 'god',
#  212: 'mind',
#  213: 'latest',
#  214: 'weekend',
#  215: 'birthday',
#  216: 'hr',
#  217: 'room',
#  218: 'guess',
#  219: 'enjoy',
#  220: 'lar',
#  221: 'receive',
#  222: 'cost',
#  223: 'eat',
#  224: 'look',
#  225: 'half',
#  226: 'play',
#  227: 'check',
#  228: 'awarded',
#  229: 'nothing',
#  230: 'game',
#  231: 'real',
#  232: 'yo',
#  233: 'another',
#  234: 'big',
#  235: 'voucher',
#  236: 'world',
#  237: 'camera',
#  238: 'landline',
#  239: 'house',
#  240: 'boy',
#  241: 'shit',
#  242: 'probably',
#  243: 'dinner',
#  244: 'sweet',
#  245: 'sir',
#  246: 'liao',
#  247: 'jus',
#  248: 'kiss',
#  249: 'ever',
#  250: 'watching',
#  251: 'pm',
#  252: 'watch',
#  253: 'might',
#  254: 'quite',
#  255: 'point',
#  256: 'early',
#  257: 'xxx',
#  258: 'speak',
#  259: 'aight',
#  260: 'called',
#  261: 'po',
#  262: 'pic',
#  263: 'apply',
#  264: 'fun',
#  265: 'bus',
#  266: 'nd',
#  267: 'part',
#  268: 'hear',
#  269: 'pa',
#  270: 'bed',
#  271: 'rate',
#  272: 'thanx',
#  273: 'video',
#  274: 'baby',
#  275: 'two',
#  276: 'actually',
#  277: 'den',
#  278: 'princess',
#  279: 'network',
#  280: 'remember',
#  281: 'pay',
#  282: 'maybe',
#  283: 'forgot',
#  284: 'worry',
#  285: 'question',
#  286: 'easy',
#  287: 'nite',
#  288: 'reach',
#  289: 'shopping',
#  290: 'orange',
#  291: 'bad',
#  292: 'code',
#  293: 'pobox',
#  294: 'left',
#  295: 'dis',
#  296: 'ah',
#  297: 'hurt',
#  298: 'award',
#  299: 'little',
#  300: 'sat',
#  301: 'put',
#  302: 'shall',
#  303: 'fuck',
#  304: 'dad',
#  305: 'selected',
#  306: 'enough',
#  307: 'looking',
#  308: 'school',
#  309: 'yr',
#  310: 'working',
#  311: 'evening',
#  312: 'leh',
#  313: 'g',
#  314: 'face',
#  315: 'everything',
#  316: 'gift',
#  317: 'made',
#  318: 'mate',
#  319: 'pound',
#  320: 'thank',
#  321: 'afternoon',
#  322: 'wk',
#  323: 'without',
#  324: 'tv',
#  325: 'xmas',
#  326: 'asked',
#  327: 'movie',
#  328: 'wif',
#  329: 'ringtone',
#  330: 'since',
#  331: 'came',
#  332: 'anyway',
#  333: 'must',
#  334: 'join',
#  335: 'sexy',
#  336: 'dream',
#  337: 'missing',
#  338: 'sound',
#  339: 'collect',
#  340: 'detail',
#  341: 'town',
#  342: 'entry',
#  343: 'uk',
#  344: 'lesson',
#  345: 'wanted',
#  346: 'run',
#  347: 'okay',
#  348: 'price',
#  349: 'pmin',
#  350: 'answer',
#  351: 'mail',
#  352: 'able',
#  353: 'hav',
#  354: 'important',
#  355: 'wake',
#  356: 'bring',
#  357: 'collection',
#  358: 'mob',
#  359: 'test',
#  360: 'juz',
#  361: 'til',
#  362: 'stay',
#  363: 'true',
#  364: 'charge',
#  365: 'plz',
#  366: 'book',
#  367: 'office',
#  368: 'change',
#  369: 'kind',
#  370: 'away',
#  371: 'plus',
#  372: 'wife',
#  373: 'update',
#  374: 'till',
#  375: 'pain',
#  376: 'hair',
#  377: 'wen',
#  378: 'else',
#  379: 'age',
#  380: 'weekly',
#  381: 'wot',
#  382: 'dude',
#  383: 'attempt',
#  384: 'de',
#  385: 'valid',
#  386: 'colour',
#  387: 'credit',
#  388: 'alright',
#  389: 'saw',
#  390: 'yesterday',
#  391: 'double',
#  392: 'trip',
#  393: 'making',
#  394: 'food',
#  395: 'top',
#  396: 'bt',
#  397: 'haf',
#  398: 'si',
#  399: 'ltdecimalgt',
#  400: 'oso',
#  401: 'missed',
#  402: 'music',
#  403: 'bored',
#  404: 'lei',
#  405: 'date',
#  406: 'ard',
#  407: 'tried',
#  408: 'delivery',
#  409: 'driving',
#  410: 'hot',
#  411: 'friendship',
#  412: 'drink',
#  413: 'either',
#  414: 'sch',
#  415: 'online',
#  416: 'brother',
#  417: 'mom',
#  418: 'second',
#  419: 'bonus',
#  420: 'address',
#  421: 'player',
#  422: 'order',
#  423: 'smoke',
#  424: 'story',
#  425: 'id',
#  426: 'wid',
#  427: 'club',
#  428: 'full',
#  429: 'head',
#  430: 'tot',
#  431: 'sae',
#  432: 'lose',
#  433: 'family',
#  434: 'together',
#  435: 'feeling',
#  436: 'goin',
#  437: 'sad',
#  438: 'set',
#  439: 'close',
#  440: 'smiling',
#  441: 'old',
#  442: 'believe',
#  443: 'noe',
#  444: 'happen',
#  445: 'walk',
#  446: 'calling',
#  447: 'post',
#  448: 'huh',
#  449: 'beautiful',
#  450: 'tscs',
#  451: 'saying',
#  452: 'drive',
#  453: 'await',
#  454: 'aft',
#  455: 'took',
#  456: 'finished',
#  457: 'busy',
#  458: 'private',
#  459: 'match',
#  460: 'leaving',
#  461: 'everyone',
#  462: 'hand',
#  463: 'gr',
#  464: 'awesome',
#  465: 'shop',
#  466: 'coz',
#  467: 'ring',
#  468: 'okie',
#  469: 'mths',
#  470: 'eve',
#  471: 'land',
#  472: 'thinking',
#  473: 'mum',
#  474: 'email',
#  475: 'w',
#  476: 'rite',
#  477: 'drop',
#  478: 'final',
#  479: 'caller',
#  480: 'forget',
#  481: 'congrats',
#  482: 'started',
#  483: 'statement',
#  484: 'taking',
#  485: 'content',
#  486: 'break',
#  487: 'company',
#  488: 'wil',
#  489: 'angry',
#  490: 'unsubscribe',
#  491: 'card',
#  492: 'sister',
#  493: 'valentine',
#  494: 'reason',
#  495: 'poly',
#  496: 'simple',
#  497: 'neva',
#  498: 'pub',
#  499: 'possible',
#  500: 'treat',
#  501: 'news',
#  502: 'tomo',
#  503: 'lucky',
#  504: 'search',
#  505: 'expires',
#  506: 'open',
#  507: 'fancy',
#  508: 'bank',
#  509: 'worth',
#  510: 'touch',
#  511: 'found',
#  512: 'sleeping',
#  513: 'choose',
#  514: 'mine',
#  515: 'whatever',
#  516: 'sun',
#  517: 'knw',
#  518: 'anyone',
#  519: 'parent',
#  520: 'alone',
#  521: 'auction',
#  522: 'available',
#  523: 'winner',
#  524: 'ha',
#  525: 'smth',
#  526: 'saturday',
#  527: 'decided',
#  528: 'song',
#  529: 'ticket',
#  530: 'prob',
#  531: 'happened',
#  532: 'uncle',
#  533: 'unredeemed',
#  534: 'identifier',
#  535: 'type',
#  536: 'hard',
#  537: 'frnd',
#  538: 'boytoy',
#  539: 'exam',
#  540: 'secret',
#  541: 'anytime',
#  542: 'far',
#  543: 'pmessage',
#  544: 'mobileupd',
#  545: 'dating',
#  546: 'welcome',
#  547: 'gd',
#  548: 'party',
#  549: 'crazy',
#  550: 'wonderful',
#  551: 'camcorder',
#  552: 'used',
#  553: 'gone',
#  554: 'hit',
#  555: 'operator',
#  556: 'friday',
#  557: 'mu',
#  558: 'nt',
#  559: 'ltd',
#  560: 'wit',
#  561: 'muz',
#  562: 'carlos',
#  563: 'finally',
#  564: 'college',
#  565: 'oredi',
#  566: 'congratulation',
#  567: 'read',
#  568: 'light',
#  569: 'project',
#  570: 'fucking',
#  571: 'visit',
#  572: 'nope',
#  573: 'outside',
#  574: 'fri',
#  575: 'pretty',
#  576: 'sea',
#  577: 'fast',
#  578: 'drug',
#  579: 'wonder',
#  580: 'lovely',
#  581: 'loving',
#  582: 'wkly',
#  583: 'info',
#  584: 'hungry',
#  585: 'seeing',
#  586: 'telling',
#  587: 'whole',
#  588: 'frnds',
#  589: 'dont',
#  590: 'quiz',
#  591: 'log',
#  592: 'course',
#  593: 'mrng',
#  594: 'darlin',
#  595: 'goodmorning',
#  596: 'case',
#  597: 'meant',
#  598: 'cd',
#  599: 'hold',
#  600: 'unlimited',
#  601: 'fone',
#  602: 'jay',
#  603: 'bout',
#  604: 'ten',
#  605: 'cum',
#  606: 'term',
#  607: 'listen',
#  608: 'snow',
#  609: 'gal',
#  610: 'wrong',
#  611: 'press',
#  612: 'valued',
#  613: 'im',
#  614: 'child',
#  615: 'almost',
#  616: 'etc',
#  617: 'move',
#  618: 'cut',
#  619: 'hee',
#  620: 'download',
#  621: 'computer',
#  622: 'mah',
#  623: 'bday',
#  624: 'felt',
#  625: 'invited',
#  626: 'msg',
#  627: 'joy',
#  628: 'f',
#  629: 'march',
#  630: 'optout',
#  631: 'side',
#  632: 'tel',
#  633: 'fr',
#  634: 'dnt',
#  635: 'single',
#  636: 'bslvyl',
#  637: 'lost',
#  638: 'reading',
#  639: 'txts',
#  640: 'currently',
#  641: 'moment',
#  642: 'motorola',
#  643: 'talking',
#  644: 'couple',
#  645: 'rock',
#  646: 'as',
#  647: 'different',
#  648: 'le',
#  649: 'savamob',
#  650: 'sub',
#  651: 'within',
#  652: 'yar',
#  653: 'happiness',
#  654: 'area',
#  655: 'paper',
#  656: 'opt',
#  657: 'sex',
#  658: 'mayb',
#  659: 'wats',
#  660: 'least',
#  661: 'earlier',
#  662: 'film',
#  663: 'luck',
#  664: 'chennai',
#  665: 'enter',
#  666: 'gas',
#  667: 'freemsg',
#  668: 'promise',
#  669: 'eh',
#  670: 'national',
#  671: 'eg',
#  672: 'hospital',
#  673: 'wow',
#  674: 'correct',
#  675: 'pas',
#  676: 'complimentary',
#  677: 'xx',
#  678: 'ampm',
#  679: 'load',
#  680: 'shower',
#  681: 'askd',
#  682: 'sending',
#  683: 'direct',
#  684: 'tired',
#  685: 'ni',
#  686: 'mr',
#  687: 'bill',
#  688: 'semester',
#  689: 'laptop',
#  690: 'blue',
#  691: 'swing',
#  692: 'die',
#  693: 'christmas',
#  694: 'via',
#  695: 'figure',
#  696: 'ish',
#  697: 'ago',
#  698: 'chikku',
#  699: 'seen',
#  700: 'rental',
#  701: 'supposed',
#  702: 'park',
#  703: 'ipod',
#  704: 'gym',
#  705: 'kid',
#  706: 'darren',
#  707: 'an',
#  708: 'sell',
#  709: 'eye',
#  710: 'store',
#  711: 'picking',
#  712: 'ugh',
#  713: 'extra',
#  714: 'sort',
#  715: 'knew',
#  716: 'photo',
#  717: 'support',
#  718: 'information',
#  719: 'surprise',
#  720: 'grin',
#  721: 'difficult',
#  722: 'john',
#  723: 'father',
#  724: 'comp',
#  725: 'usf',
#  726: 'request',
#  727: 'link',
#  728: 'comin',
#  729: 'cheer',
#  730: 'charged',
#  731: 'confirm',
#  732: 'abiola',
#  733: 'crave',
#  734: 'checking',
#  735: 'save',
#  736: 'loan',
#  737: 'page',
#  738: 'entered',
#  739: 'dogging',
#  740: 'txting',
#  741: 'lovable',
#  742: 'wine',
#  743: 'safe',
#  744: 'bath',
#  745: 'orchard',
#  746: 'kate',
#  747: 'lover',
#  748: 'wana',
#  749: 'hmv',
#  750: 'somebody',
#  751: 'return',
#  752: 'small',
#  753: 'discount',
#  754: 'slow',
#  755: 'mm',
#  756: 'india',
#  757: 'hmm',
#  758: 'asking',
#  759: 'rent',
#  760: 'lady',
#  761: 'door',
#  762: 'train',
#  763: 'laugh',
#  764: 'idea',
#  765: 'whenever',
#  766: 'truth',
#  767: 'heard',
#  768: 'frm',
#  769: 'fantasy',
#  770: 'fact',
#  771: 'loved',
#  772: 'slowly',
#  773: 'police',
#  774: 'nah',
#  775: 'callertune',
#  776: 'copy',
#  777: 'reward',
#  778: 'wap',
#  779: 'england',
#  780: 'turn',
#  781: 'catch',
#  782: 'oops',
#  783: 'reached',
#  784: 'joke',
#  785: 'situation',
#  786: 'short',
#  787: 'rply',
#  788: 'representative',
#  789: 'gave',
#  790: 'men',
#  791: 'del',
#  792: 'spend',
#  793: 'bathe',
#  794: 'bcoz',
#  795: 'teach',
#  796: 'road',
#  797: 'kick',
#  798: 'admirer',
#  799: 'deep',
#  800: 'leaf',
#  801: 'stupid',
#  802: 'sim',
#  803: 'somewhere',
#  804: 'immediately',
#  805: 'custcare',
#  806: 'met',
#  807: 'ex',
#  808: 'woke',
#  809: 'yep',
#  810: 'voice',
#  811: 'ldn',
#  812: 'booked',
#  813: 'remove',
#  814: 'nyt',
#  815: 'monday',
#  816: 'water',
#  817: 'opinion',
#  818: 'member',
#  819: 'hoping',
#  820: 'across',
#  821: 'warm',
#  822: 'cheap',
#  823: 'study',
#  824: 'ho',
#  825: 'gap',
#  826: 'fantastic',
#  827: 'glad',
#  828: 'wishing',
#  829: 'summer',
#  830: 'gettin',
#  831: 'understand',
#  832: 'poor',
#  833: 'otherwise',
#  834: 'ntt',
#  835: 'rd',
#  836: 'na',
#  837: 'doctor',
#  838: 'energy',
#  839: 'shes',
#  840: 'write',
#  841: 'cover',
#  842: 'doin',
#  843: 'med',
#  844: 'empty',
#  845: 'la',
#  846: 'cup',
#  847: 'std',
#  848: 'seriously',
#  849: 'suck',
#  850: 'worried',
#  851: 'sick',
#  852: 'decide',
#  853: 'forever',
#  854: 'rain',
#  855: 'bos',
#  856: 'specially',
#  857: 'flight',
#  858: 'ending',
#  859: 'buying',
#  860: 'sunshine',
#  861: 'sony',
#  862: 'lazy',
#  863: 'lect',
#  864: 'completely',
#  865: 'hmmm',
#  866: 'staying',
#  867: 'spoke',
#  868: 'especially',
#  869: 'studying',
#  870: 'trust',
#  871: 'using',
#  872: 'deal',
#  873: 'mrt',
#  874: 'disturb',
#  875: 'unless',
#  876: 'rose',
#  877: 'sport',
#  878: 'accept',
#  879: 'normal',
#  880: 'rest',
#  881: 'merry',
#  882: 'pete',
#  883: 'access',
#  884: 'round',
#  885: 'urself',
#  886: 'bluetooth',
#  887: 'reference',
#  888: 'brings',
#  889: 'mistake',
#  890: 'result',
#  891: 'style',
#  892: 'meh',
#  893: 'near',
#  894: 'silent',
#  895: 'hotel',
#  896: 'noon',
#  897: 'forwarded',
#  898: 'starting',
#  899: 'xy',
#  900: 'bold',
#  901: 'seems',
#  902: 'add',
#  903: 'wwwgetzedcouk',
#  904: 'bid',
#  905: 'charity',
#  906: 'fall',
#  907: 'tampa',
#  908: 'user',
#  909: 'sale',
#  910: 'gay',
#  911: 'hiya',
#  912: 'convey',
#  913: 'digital',
#  914: 'nobody',
#  915: 'mode',
#  916: 'wondering',
#  917: 'others',
#  918: 'bb',
#  919: 'frens',
#  920: 'tht',
#  921: 'reaching',
#  922: 'didnt',
#  923: 'excuse',
#  924: 'thinkin',
#  925: 'sitting',
#  926: 'flag',
#  927: 'colleague',
#  928: 'entitled',
#  929: 'anymore',
#  930: 'hl',
#  931: 'sunday',
#  932: 'mark',
#  933: 'pizza',
#  934: 'quick',
#  935: 'replying',
#  936: 'roommate',
#  937: 'letter',
#  938: 'nigeria',
#  939: 'ice',
#  940: 'cinema',
#  941: 'stand',
#  942: 'spent',
#  943: 'trouble',
#  944: 'planning',
#  945: 'ave',
#  946: 'apartment',
#  947: 'inc',
#  948: 'paying',
#  949: 'bak',
#  950: 'dvd',
#  951: 'pray',
#  952: 'sometimes',
#  953: 'goto',
#  954: 'freephone',
#  955: 'however',
#  956: 'dead',
#  957: 'slept',
#  958: 'gt',
#  959: 'file',
#  960: 'sign',
#  961: 'street',
#  962: 'youfind',
#  963: 'rreveal',
#  964: 'specialcall',
#  965: 'goodnight',
#  966: 'power',
#  967: 'record',
#  968: 'woman',
#  969: 'fixed',
#  970: 'wiv',
#  971: 'weed',
#  972: 'hgsuitelands',
#  973: 'rowwjhl',
#  974: 'mei',
#  975: 'picture',
#  976: 'facebook',
#  977: 'none',
#  978: 'yahoo',
#  979: 'aha',
#  980: 'funny',
#  981: 'giving',
#  982: 'din',
#  983: 'mp',
#  984: 'fat',
#  985: 'finger',
#  986: 'self',
#  987: 'workin',
#  988: 'daddy',
#  989: 'present',
#  990: 'indian',
#  991: 'euro',
#  992: 'future',
#  993: 'longer',
#  994: 'pc',
#  995: 'tuesday',
#  996: 'student',
#  997: 'tonite',
#  998: 'library',
#  999: 'space',
#  1000: 'slave',
#  ...}

# %%
from keras_preprocessing.sequence import pad_sequences

# %%
max_length_sequence = max([len(i) for i in text_to_sequence])
 # finding the length of largest sequence
padded_sms_sequence = pad_sequences(text_to_sequence, maxlen=max_length_sequence, padding="pre") 
padded_sms_sequence
# Out:
# array([[   0,    0,    0, ...,    9, 3576,   70],
#        [   0,    0,    0, ..., 1173,  328, 1539],
#        [   0,    0,    0, ..., 2413,  263, 2414],
#        ...,
#        [   0,    0,    0, ..., 1024, 7818, 3573],
#        [   0,    0,    0, ...,  789,   67,    5],
#        [   0,    0,    0, ..., 2147,  363,  145]], dtype=int32)

# %%
VOC_SIZE = len(tokenizer.word_index)+1
def create_model():
    
      model = Sequential()
      model.add(Embedding(VOC_SIZE, 32, input_length=max_length_sequence))
      model.add(LSTM(100))
      model.add(Dropout(0.4))
      model.add(Dense(20, activation="relu"))
      model.add(Dropout(0.5))
      model.add(Dense(1, activation = "sigmoid"))
      return model
lstm_model = create_model()
lstm_model.compile(optimizer = "adam", loss = "binary_crossentropy", metrics = ["accuracy"])
lstm_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 79, 32)            250240
#
#  lstm (LSTM)                 (None, 100)               53200
#
#  dropout (Dropout)           (None, 100)               0
#
#  dense (Dense)               (None, 20)                2020
#
#  dropout_1 (Dropout)         (None, 20)                0
#
#  dense_1 (Dense)             (None, 1)                 21
#
# =================================================================
# Total params: 305,481
# Trainable params: 305,481
# Non-trainable params: 0
# _________________________________________________________________

# %%
lstm_model.fit(padded_sms_sequence, y, epochs = 5, batch_size=16, validation_split=0.2)
# Out:
# Epoch 1/5
# 279/279 [==============================] - 16s 48ms/step - loss: 0.2062 - accuracy: 0.9345 - val_loss: 0.0604 - val_accuracy: 0.9830
# Epoch 2/5
# 279/279 [==============================] - 13s 45ms/step - loss: 0.0502 - accuracy: 0.9897 - val_loss: 0.0593 - val_accuracy: 0.9830
# Epoch 3/5
# 279/279 [==============================] - 13s 45ms/step - loss: 0.0254 - accuracy: 0.9966 - val_loss: 0.0761 - val_accuracy: 0.9803
# Epoch 4/5
# 279/279 [==============================] - 13s 48ms/step - loss: 0.0104 - accuracy: 0.9978 - val_loss: 0.1171 - val_accuracy: 0.9668
# Epoch 5/5
# 279/279 [==============================] - 13s 45ms/step - loss: 0.0086 - accuracy: 0.9980 - val_loss: 0.0981 - val_accuracy: 0.9821

# %%
pickle.dump(tokenizer, open("sms_spam_tokenizer.pkl", "wb"))
pickle.dump(lstm_model, open("lstm_model.pkl", "wb"))
# Out:
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
